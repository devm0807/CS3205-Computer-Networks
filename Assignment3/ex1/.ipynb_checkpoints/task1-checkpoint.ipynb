# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import re

# %%
### Generated traceroute log data using the script given ###
# Load traceroute log data
with open('traceroute_log.txt', 'r') as f:
    log_data = f.read()

# Regex pattern to extract IPs and valid RTTs
pattern = re.compile(r'(\d+\.\d+\.\d+\.\d+).*?((?:\d+\.\d+\s*ms\s*)+)')

# Extract all matches
matches = pattern.findall(log_data)

#  Total valid RTT entries
total_valid_rtt = len(matches)
print(f"Total valid RTT entries: {total_valid_rtt}") # Solution to 1(a)
# Out:
# Total valid RTT entries: 5279

# %%
### Finding number of unique router IPs, and other statistics ###

rtt_data = defaultdict(list)

for match in matches:
    ip = match[0]
    rtt_values = re.findall(r'(\d+\.\d+)\s*ms', match[1])
    for rtt in rtt_values:
        rtt_data[ip].append(float(rtt))

# Calculate statistics
rtt_stats = {}
for ip, values in rtt_data.items():
    rtt_stats[ip] = {
        'avg_rtt': np.mean(values),
        'std_dev': np.std(values),
        'measurement_count': len(values)
    }

# Sort by standard deviation descending
top_std = sorted(rtt_stats.items(), key=lambda x: x[1]['std_dev'], reverse=True)[:5]

# Print results
print(f"{'Router IP':16} | {'Average RTT':14} | {'Standard Deviation':20} | {'Measurement Count':17}")
for ip, stats in rtt_stats.items():
    print(f"{ip:16} | {stats['avg_rtt']:11.2f} ms | {stats['std_dev']:17.2f} ms | {stats['measurement_count']:17}")

print("\nTop 5 routers by RTT standard deviation:")
for ip, stats in top_std:
    print(f"{ip:16} | {stats['avg_rtt']:11.2f} ms | {stats['std_dev']:17.2f} ms | {stats['measurement_count']:17}")
# Out:
# Router IP        | Average RTT    | Standard Deviation   | Measurement Count
# 192.168.85.208   |        3.00 ms |              4.35 ms |               450
# 255.0.0.0        |       36.55 ms |             18.34 ms |               450
# 255.0.0.2        |       43.33 ms |             23.85 ms |               450
# 255.0.0.3        |       45.04 ms |             27.49 ms |               450
# 172.27.251.99    |       47.68 ms |             28.77 ms |               240
# 172.27.251.98    |       50.05 ms |             33.19 ms |               210
# 192.168.142.20   |       48.01 ms |             37.17 ms |                56
# 192.168.142.22   |       44.83 ms |             20.09 ms |                59
# 192.168.138.226  |       46.74 ms |             17.11 ms |                54
# 103.198.140.174  |       78.63 ms |             34.07 ms |               208
# 103.198.140.105  |      177.99 ms |             22.43 ms |                25
# 103.198.140.54   |      198.03 ms |             62.78 ms |                34
# 103.198.140.211  |      173.88 ms |             31.12 ms |                31
# 185.1.47.13      |      194.62 ms |             61.81 ms |                33
# 197.234.113.76   |      295.62 ms |             45.09 ms |                47
# 103.198.140.215  |      183.35 ms |             62.42 ms |                38
# 197.234.112.84   |      271.06 ms |             19.72 ms |                11
# 192.168.138.224  |       43.36 ms |             18.36 ms |                52
# 192.168.138.222  |       51.28 ms |             34.67 ms |                53
# 192.168.142.16   |       55.77 ms |             45.73 ms |                62
# 103.198.140.213  |      191.27 ms |             41.89 ms |                27
# 103.198.140.27   |      183.18 ms |             40.86 ms |                26
# 103.198.140.176  |       64.20 ms |             27.55 ms |               217
# 41.60.199.193    |      312.36 ms |             10.89 ms |                 2
# 41.173.0.113     |      345.06 ms |              0.00 ms |                 1
# 41.173.0.133     |      317.67 ms |              1.24 ms |                 2
# 41.60.199.91     |      308.57 ms |             15.56 ms |                 4
# 197.155.94.223   |      334.51 ms |              1.84 ms |                 2
# 41.60.199.191    |      330.03 ms |              3.83 ms |                 2
# 41.173.0.119     |      320.93 ms |              1.56 ms |                 2
# 41.173.0.155     |      339.48 ms |              0.00 ms |                 1
# 41.173.0.137     |      322.50 ms |              5.32 ms |                 2
# 41.173.0.151     |      306.12 ms |              0.00 ms |                 1
# 41.173.0.157     |      311.64 ms |              0.00 ms |                 1
# 197.155.88.5     |      311.68 ms |              0.00 ms |                 1
# 41.173.0.135     |      325.98 ms |              1.10 ms |                 2
# 41.173.0.159     |      322.39 ms |             13.91 ms |                 2
# 197.155.94.63    |      313.32 ms |              0.00 ms |                 1
# 41.173.0.131     |      324.49 ms |              0.00 ms |                 1
# 197.155.94.69    |      326.80 ms |              0.00 ms |                 1
# 105.16.11.194    |      351.44 ms |             14.95 ms |                 2
# 105.16.29.10     |      349.81 ms |             21.43 ms |                23
# 105.16.28.10     |      358.37 ms |             18.92 ms |                22
# 105.16.11.178    |      346.25 ms |              0.00 ms |                 1
# 105.16.14.193    |      359.12 ms |              0.27 ms |                 2
# 105.22.47.134    |      344.49 ms |             16.07 ms |                30
# 196.46.212.2     |      380.31 ms |             13.44 ms |                30
# 102.220.219.69   |      388.50 ms |             20.54 ms |                31
# 102.220.216.169  |      396.57 ms |             18.49 ms |                23
# 196.46.196.241   |      373.43 ms |             15.05 ms |                30
# 196.46.214.249   |      406.86 ms |             18.15 ms |                26
# 105.25.160.125   |      350.48 ms |             19.01 ms |                14
# 105.16.11.169    |      325.02 ms |              0.00 ms |                 1
# 105.16.11.77     |      355.07 ms |             17.44 ms |                 5
# 105.25.161.113   |      344.58 ms |             21.67 ms |                 4
# 105.16.15.253    |      388.85 ms |             26.65 ms |                 3
# 105.25.160.149   |      380.12 ms |              0.00 ms |                 1
# 105.25.160.174   |      365.44 ms |              2.15 ms |                 2
# 105.16.15.249    |      363.29 ms |             20.82 ms |                 3
# 105.25.160.178   |      355.86 ms |              0.00 ms |                 1
# 105.25.160.153   |      341.87 ms |              8.05 ms |                 3
# 105.25.161.117   |      387.12 ms |              0.00 ms |                 1
# 5.11.12.112      |      351.39 ms |             10.14 ms |                31
# 41.175.159.31    |      345.01 ms |              0.00 ms |                 1
# 41.175.159.6     |      375.94 ms |             12.80 ms |                11
# 46.17.232.65     |      383.39 ms |             13.31 ms |                10
# 41.175.222.218   |      374.17 ms |             14.80 ms |                 7
# 41.175.159.34    |      400.51 ms |              1.70 ms |                 2
# 46.17.232.121    |      378.52 ms |             14.21 ms |                10
# 41.175.159.70    |      379.26 ms |             13.79 ms |                32
# 41.175.159.15    |      382.02 ms |             11.09 ms |                17
# 41.175.159.36    |      373.00 ms |             11.11 ms |                 3
# 46.17.232.76     |      375.36 ms |             12.86 ms |                21
# 197.211.213.30   |      382.61 ms |             14.25 ms |                27
# 41.175.222.253   |      352.58 ms |             12.71 ms |                 4
# 46.17.232.57     |      404.81 ms |             17.80 ms |                10
# 41.175.159.2     |      364.06 ms |              6.48 ms |                10
# 41.175.159.1     |      366.44 ms |              8.74 ms |                13
# 41.175.223.171   |      378.17 ms |             10.48 ms |                 2
# 41.175.222.216   |      370.35 ms |              8.75 ms |                 2
# 41.175.223.169   |      364.37 ms |              9.14 ms |                 4
# 41.175.159.51    |      370.44 ms |              0.00 ms |                 1
# 41.175.159.4     |      374.53 ms |              0.00 ms |                 1
# 41.175.223.175   |      357.67 ms |             14.33 ms |                 2
# 41.175.222.214   |      377.16 ms |             11.17 ms |                 2
# 41.175.242.17    |      363.60 ms |              0.00 ms |                 1
#
# Top 5 routers by RTT standard deviation:
# 81.52.166.153    |      245.29 ms |             99.37 ms |                34
# 130.117.48.145   |      190.76 ms |             84.49 ms |                26
# 130.117.15.58    |      186.22 ms |             69.24 ms |                19
# 197.215.159.82   |      191.96 ms |             64.28 ms |                33
# 103.198.140.54   |      198.03 ms |             62.78 ms |                34

# %%
import re
import numpy as np

IITM = (12.99, 80.23)

def parse_traceroute_logs(filename):
    ### Parsing traceroute logs while preserving hop sequences ###
    
    iterations = []
    iteration = []
    vertex_ips = set()

    # Combined regex pattern for efficiency
    traceroute_start = re.compile(r'traceroute to', re.IGNORECASE)
    ip_pattern = re.compile(r'\d+\.\d+\.\d+\.\d+')
    rtt_pattern = re.compile(r'(\d+\.\d+)\s*ms')
    loc_pattern = re.compile(r'\((.*?)\)')
    geo_pattern = re.compile(r'loc:\s*(-?\d+\.\d+),(-?\d+\.\d+)')

    with open(filename, 'r') as f:
        for line in f:
            if traceroute_start.search(line):
                if iteration:
                    iterations.append(iteration)
                    iteration = []
                continue

            # Extract first IP and RTT values
            ip_match = ip_pattern.search(line)
            rtt_matches = rtt_pattern.findall(line)
            
            if not ip_match or not rtt_matches:
                continue

            ip = ip_match.group()
            avg_rtt = np.mean([float(rtt) for rtt in rtt_matches])

            # Determine coordinates
            lat, lon = IITM
            loc_match = loc_pattern.search(line)
            geo_match = geo_pattern.search(line)
            
            if loc_match:
                loc_str = loc_match.group(1)
                if "IIT Madras" not in loc_str and geo_match:
                    lat, lon = map(float, geo_match.groups())

            # Update data structures
            vertex_ips.add((ip, (lat, lon)))
            iteration.append((lat, lon, avg_rtt))

        # Add final iteration
        if iteration:
            iterations.append(iteration)

    return iterations

# %%
# print(parse_traceroute_logs('traceroute_log.txt'))

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(coord1, coord2, unit='km'):
    ### Computing haversine distances (spherical distances) ###
    
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    
    # Convert degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Earth radius in km
    
    distance = c * r
    return distance * 1000 if unit == 'm' else distance

class UnionFind:
    def __init__(self, size):
        self.parent = list(range(size))
    
    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]
    
    def union(self, x, y):
        fx = self.find(x)
        fy = self.find(y)
        if fx != fy:
            self.parent[fy] = fx

def merge_locations(iterations, max_distance=50): # as described in question
    # Extract unique coordinates with original order
    points = []
    seen = set()
    for iteration in iterations:
        for (lat, lon, _) in iteration:
            if (lat, lon) not in seen:
                seen.add((lat, lon))
                points.append((lat, lon))
    
    # Initialize Union-Find
    uf = UnionFind(len(points))
    
    # Connect nearby points
    for i in range(len(points)):
        for j in range(i+1, len(points)):
            if haversine(points[i], points[j], unit='km') <= max_distance:
                uf.union(i, j)
    
    # Group clusters and calculate centroids
    clusters = {}
    for idx, point in enumerate(points):
        root = uf.find(idx)
        if root not in clusters:
            clusters[root] = []
        clusters[root].append(point)
    
    # Calculate cluster centers (mean of coordinates)
    merged_vertices = []
    for cluster in clusters.values():
        avg_lat = np.mean([p[0] for p in cluster])
        avg_lon = np.mean([p[1] for p in cluster])
        merged_vertices.append((avg_lat, avg_lon))
    
    return merged_vertices

# %%
def calculate_edges(iterations, merged_vertices, max_distance=50):
    ### Calculate inter-vertex edges with averaged RTT differences using spatial clustering ###
    
    edge_data = defaultdict(list)
    
    for iteration in iterations:
        valid_hops = [
            (min(merged_vertices, key=lambda n: haversine((lat, lon), n)), rtt)
            for lat, lon, rtt in iteration
            if haversine((lat, lon), min(merged_vertices, key=lambda n: haversine((lat, lon), n)), unit='km') <= max_distance
        ]
        
        # Calculate RTT differences between consecutive valid vertices
        for i in range(1, len(valid_hops)):
            prev_vertex, prev_rtt = valid_hops[i-1]
            curr_vertex, curr_rtt = valid_hops[i]
            
            if prev_vertex != curr_vertex:
                rtt_diff = curr_rtt - prev_rtt
                if rtt_diff > 0:
                    edge_data[(prev_vertex, curr_vertex)].append(rtt_diff)
    
    # Calculate mean RTT difference for each edge
    return {edge: np.mean(values) for edge, values in edge_data.items()}

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

def plot_network(merged_vertices, edges):
    ### Question 1(c) : Plotting router locations and connectivity using Cartopy ###
    
    
    fig = plt.figure(figsize=(15, 10))
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    # Add base map features
    ax.add_feature(cfeature.LAND, facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.gridlines(draw_labels=True, linestyle='--', alpha=0.7)

    # Plot network vertices (converting (lat,lon) to (lon,lat) for Cartopy)
    for vertex in merged_vertices:
        lat, lon = vertex
        ax.plot(lon, lat, 'ro', 
                markersize=8, 
                alpha=0.7,
                transform=ccrs.PlateCarree())

    # Plot edges with latency-based coloring
    if edges:
        weights = list(edges.values())
        norm = Normalize(vmin=min(weights), vmax=max(weights))
        cmap = plt.cm.viridis

        for (src, dst), weight in edges.items():
            src_lat, src_lon = src
            dst_lat, dst_lon = dst
            ax.plot([src_lon, dst_lon], [src_lat, dst_lat],
                    color=cmap(norm(weight)),
                    linewidth=1.5,
                    alpha=0.6,
                    transform=ccrs.PlateCarree())

        # Add colorbar
        sm = ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array(weights)
        cbar = plt.colorbar(sm, ax=ax, 
                            orientation='vertical',
                            pad=0.02,
                            aspect=30)
        cbar.set_label('Latency Difference (ms)')

    plt.title("Global Network Latency Visualization")
    plt.show()

# %%
# Execution flow
iterations = parse_traceroute_logs('traceroute_log.txt')
merged_vertices = merge_locations(iterations)
edges = calculate_edges(iterations, merged_vertices)
plot_network(merged_vertices, edges)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

### Scatter plot for 1(d) ###

# Calculate distances and latencies
physical_distances = []
latency_differences = []

for (src, dst), latency in edges.items():
    distance = haversine(src, dst, unit='km')
    physical_distances.append(distance)
    latency_differences.append(latency)

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(physical_distances, latency_differences)

# Plot scatter with trend line
plt.figure(figsize=(12, 8))
plt.scatter(physical_distances, latency_differences, alpha=0.7, label='Edge')
plt.plot(
    physical_distances, 
    slope * np.array(physical_distances) + intercept, 
    color='red', 
    linestyle='--',
    label=f'Trend Line (r={r_value:.2f})'
)

plt.xlabel('Distance (km)')
plt.ylabel('Latency Difference (ms)')
plt.title('Latency vs Distance')
plt.legend()
plt.grid(True)
plt.show()

# %%
import re

def analyze_load_balancing(filename):
    """Find hops with 2+ routers (per-packet load balancing), show locations and ISP."""
    total_cases = 0
    cases = []

    # Regex to extract router info
    router_re = re.compile(
        r'(\d+\.\d+\.\d+\.\d+).*?AS\d+\s+([^,]+).*?loc:\s*(-?\d+\.\d+),(-?\d+\.\d+)'
    )

    with open(filename, 'r') as f:
        for line in f:
            # Only process lines that look like hops
            if not re.match(r'^\s*\d+\s+', line):
                continue

            routers = router_re.findall(line)
            unique_ips = {ip for ip, isp, lat, lon in routers}
            if len(unique_ips) >= 2:
                total_cases += 1
                isp = routers[0][1]
                cases.append([(ip, isp, float(lat), float(lon)) for ip, isp, lat, lon in routers])

    print(f"Total load balancing cases (2+): {total_cases}\n")
    
    for idx, routers in enumerate(cases, 1):
        print(f"Case {idx}:")
        for ip, isp, lat, lon in routers:
            print(f"  {ip:15} | {isp:30} | ({lat:.4f}, {lon:.4f})")
        print()

analyze_load_balancing('traceroute_log.txt') # 1(e): analyzing per packet load balancing
# Out:
# Total load balancing cases (2+): 1278
#
# Case 1:
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 2:
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 3:
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 4:
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 5:
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 6:
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 7:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 8:
#   185.1.47.13     | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 9:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 10:
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 11:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 12:
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 13:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 14:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 15:
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 16:
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 17:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 18:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 19:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 20:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 21:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 22:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 23:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 24:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.56  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 25:
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 26:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 27:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 28:
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 29:
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 30:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 31:
#   185.1.47.13     | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 32:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   185.1.47.13     | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 33:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 34:
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 35:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 36:
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 37:
#   197.234.113.76  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#   197.234.112.84  | Paratus Telecommunications Limited | (-8.8368, 13.2343)
#
# Case 38:
#   103.198.140.85  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 39:
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 40:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 41:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#
# Case 42:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 43:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 44:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 45:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 46:
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 47:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 48:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 49:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 50:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 51:
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 52:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 53:
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 54:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 55:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 56:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 57:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 58:
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 59:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   103.198.140.85  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 60:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 61:
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 62:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 63:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 64:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 65:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 66:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 67:
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 68:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 69:
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.85  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.79  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 70:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 71:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 72:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#
# Case 73:
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 74:
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 75:
#   103.198.140.79  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 76:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.244.240  | MTN SA                         | (52.3740, 4.8897)
#
# Case 77:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 78:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 79:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 80:
#   41.181.190.185  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 81:
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#
# Case 82:
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.251.189  | MTN SA                         | (-26.2023, 28.0436)
#
# Case 83:
#   41.181.251.38   | MTN SA                         | (-26.2023, 28.0436)
#   41.181.105.49   | MTN SA                         | (45.4643, 9.1895)
#
# Case 84:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 85:
#   41.242.112.228  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 86:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 87:
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#
# Case 88:
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 89:
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 90:
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 91:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 92:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 93:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   195.66.227.225  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 94:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 95:
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 96:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 97:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 98:
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 99:
#   41.242.112.228  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 100:
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#
# Case 101:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 102:
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 103:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.112.238  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 104:
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#   195.66.227.225  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 105:
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 106:
#   195.66.227.225  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 107:
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 108:
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 109:
#   195.66.227.225  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#
# Case 110:
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 111:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 112:
#   103.198.140.56  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 113:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 114:
#   195.66.227.225  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 115:
#   195.66.227.225  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 116:
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 117:
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#
# Case 118:
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#   212.52.158.230  | ONATEL (Office National des Telecommunications | (12.3657, -1.5339)
#
# Case 119:
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   195.66.227.225  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 120:
#   41.242.112.238  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 121:
#   102.221.28.246  | Broadspectrum Limited          | (5.5560, -0.1969)
#   195.66.227.225  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 122:
#   195.66.227.225  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   41.242.112.226  | DOLPHIN TELECOMMUNICATION LIMITED | (5.5560, -0.1969)
#
# Case 123:
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.242.115.161  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 124:
#   195.66.227.225  | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#   41.242.112.68   | DOLPHIN TELECOMMUNICATION LIMITED | (6.4541, 3.3947)
#
# Case 125:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 126:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 127:
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 128:
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 129:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 130:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 131:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 132:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 133:
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 134:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 135:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 136:
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 137:
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 138:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 139:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 140:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 141:
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 142:
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 143:
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 144:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 145:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 146:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 147:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 148:
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 149:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 150:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 151:
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 152:
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 153:
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 154:
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 155:
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 156:
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 157:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 158:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 159:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 160:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 161:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 162:
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 163:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 164:
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 165:
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 166:
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 167:
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 168:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 169:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 170:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 171:
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 172:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#
# Case 173:
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 174:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 175:
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 176:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 177:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.76.162   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 178:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.62.114   | Cogent Communications          | (38.7167, -9.1333)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 179:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 180:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 181:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 182:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 183:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 184:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 185:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 186:
#   103.198.140.211 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#
# Case 187:
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 188:
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 189:
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 190:
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 191:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 192:
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 193:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 194:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 195:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 196:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 197:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 198:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 199:
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 200:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 201:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 202:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 203:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 204:
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 205:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 206:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 207:
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 208:
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 209:
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 210:
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 211:
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.61.213   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 212:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 213:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 214:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 215:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 216:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   154.54.62.114   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 217:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 218:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 219:
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#   49.45.4.65      | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 220:
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 221:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#
# Case 222:
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.102   | Cogent Communications          | (41.5503, -8.4200)
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 223:
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 224:
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 225:
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.76.162   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 226:
#   41.75.94.205    | Mainone Cable Company          | (6.4541, 3.3947)
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 227:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.113.144.169 | Mainone Cable Company          | (6.4541, 3.3947)
#
# Case 228:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 229:
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 230:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 231:
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 232:
#   154.54.39.225   | Cogent Communications          | (43.2627, -2.9253)
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 233:
#   154.54.56.125   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#
# Case 234:
#   154.54.37.246   | Cogent Communications          | (43.2970, 5.3811)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 235:
#   154.54.62.114   | Cogent Communications          | (38.7167, -9.1333)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 236:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.61.106   | Cogent Communications          | (41.5503, -8.4200)
#
# Case 237:
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#   154.54.38.238   | Cogent Communications          | (43.2627, -2.9253)
#   154.54.63.189   | Cogent Communications          | (38.7167, -9.1333)
#
# Case 238:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 239:
#   41.75.81.46     | Mainone Cable Company          | (6.4541, 3.3947)
#   149.6.144.98    | Cogent Communications          | (6.4541, 3.3947)
#
# Case 240:
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.188.97   | CAMTEL                         | (4.0483, 9.7043)
#
# Case 241:
#   165.210.32.1    | CAMTEL                         | (4.0483, 9.7043)
#   154.72.175.6    | CAMTEL                         | (4.0483, 9.7043)
#
# Case 242:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.56  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 243:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 244:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 245:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 246:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 247:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 248:
#   103.198.140.56  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 249:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 250:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 251:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 252:
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 253:
#   103.198.140.27  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 254:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 255:
#   103.198.140.43  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 256:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 257:
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 258:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.45  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 259:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   149.14.125.1    | Cogent Communications          | (43.2970, 5.3811)
#
# Case 260:
#   154.54.38.202   | Cogent Communications          | (43.2970, 5.3811)
#   103.198.140.54  | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.29  | Reliance Jio Infocomm Pte Ltd Singapore | (13.0878, 80.2785)
#
# Case 261:
#   103.198.140.215 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   130.117.15.26   | Cogent Communications          | (43.2970, 5.3811)
# ...
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.34   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1198:
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1199:
#   41.175.159.36   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1200:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1201:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1202:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1203:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1204:
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.175.222.253  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1205:
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1206:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.223.171  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1207:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1208:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1209:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#
# Case 1210:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1211:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#
# Case 1212:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1213:
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1214:
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.222.216  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1215:
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1216:
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#
# Case 1217:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#
# Case 1218:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1219:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1220:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1221:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1222:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1223:
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.36   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#
# Case 1224:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.36   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1225:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1226:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1227:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#
# Case 1228:
#   103.198.140.85  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1229:
#   41.175.222.253  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1230:
#   41.175.223.169  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.79  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   41.175.223.171  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1231:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1232:
#   41.175.159.51   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.4    | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1233:
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1234:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1235:
#   103.198.140.85  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.191 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1236:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.79  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1237:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.223.175  | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#
# Case 1238:
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1239:
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1240:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1241:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1242:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1243:
#   103.198.140.213 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1244:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.79  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1245:
#   41.175.222.214  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1246:
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1247:
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1248:
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.222.216  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1249:
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1250:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1251:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1252:
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#
# Case 1253:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1254:
#   103.198.140.105 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1255:
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1256:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1257:
#   41.175.223.169  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.222.253  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1258:
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1259:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.2    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.6    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1260:
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1261:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1262:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#
# Case 1263:
#   197.211.213.30  | Zimbabwe Online                | (-20.1500, 28.5833)
#   46.17.232.76    | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#
# Case 1264:
#   103.198.140.75  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1265:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.77  | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#
# Case 1266:
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1267:
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.34   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1268:
#   41.175.222.218  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.57    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1269:
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.242.17   | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1270:
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#
# Case 1271:
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#
# Case 1272:
#   103.198.140.193 | Reliance Jio Infocomm Pte Ltd Singapore | (1.2897, 103.8501)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#   103.198.140.176 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1273:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   103.198.140.174 | Reliance Jio Infocomm Pte Ltd Singapore | (19.0728, 72.8826)
#
# Case 1274:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.223.169  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1275:
#   5.11.12.112     | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   41.175.222.253  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1276:
#   41.175.222.214  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#   46.17.232.65    | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#
# Case 1277:
#   41.175.223.175  | Liquid Telecommunications Ltd  | (-15.7850, 35.0085)
#   41.175.159.15   | Liquid Telecommunications Ltd  | (-15.4067, 28.2871)
#   41.175.223.169  | Liquid Telecommunications Ltd  | (-26.2023, 28.0436)
#
# Case 1278:
#   41.175.159.1    | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   41.175.159.70   | Liquid Telecommunications Ltd  | (-22.9456, 30.4850)
#   46.17.232.121   | Liquid Telecommunications Ltd  | (-20.1500, 28.5833)

# %%
def analyze_common_routers(filename):
    """Identify frequently occurring routers outside India with location/ISP details"""
    router_stats = defaultdict(lambda: {'count': 0, 'locations': set(), 'isps': set()})

    # Enhanced regex pattern to capture router details
    router_re = re.compile(
        r'(\d+\.\d+\.\d+\.\d+)\s+'          # IP address
        r'\(([^,]+),\s*([A-Z]{2}),\s*'      # City and country code
        r'(?:AS\d+\s+)?([^,]+),\s*'         # ISP (optional AS number)
        r'loc:\s*(-?\d+\.\d+),(-?\d+\.\d+)' # Coordinates
    )

    with open(filename, 'r') as f:
        for line in f:
            # Skip header/traceroute command lines
            if line.startswith(('traceroute', '===')) or not line.strip():
                continue
            
            # Process each router in the line
            for match in router_re.finditer(line):
                ip, city, country, isp, lat, lon = match.groups()
                
                # Skip Indian routers and local networks
                if country == 'IN' or 'local' in isp.lower():
                    continue
                
                # Record router details
                router_stats[ip]['count'] += 1
                router_stats[ip]['locations'].add(f"{city}, {country} ({lat},{lon})")
                router_stats[ip]['isps'].add(isp)

    # Filter routers appearing at least 2 times
    common_routers = {ip: data for ip, data in router_stats.items() if data['count'] >= 2}

    # Print results
    print("Frequent International Routers:")
    print("{:<15} {:<6} {:<25} {}".format("IP", "Count", "Locations", "ISPs"))
    for ip, data in sorted(common_routers.items(), key=lambda x: -x[1]['count']):
        locs = ', '.join(sorted(data['locations'])[:2])
        isps = ', '.join(sorted(data['isps']))
        print(f"{ip:<15} {data['count']:<6} {locs:<25} {isps}")

analyze_common_routers('traceroute_log.txt') # 1(f): Identifying commonly accessed routers outside India
# Out:
# Frequent International Routers:
# IP              Count  Locations                 ISPs
# 154.126.20.242  105    Antananarivo, MG (-18.9137,47.5361) Telecom Malagasy
#